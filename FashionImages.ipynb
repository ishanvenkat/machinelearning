# %% [markdown]
# Import necessary libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras import datasets, layers, models

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Specify images batch size and dimensions

# %%
batch_size = 32
img_width = 28
img_height = 28

# %% [markdown]
# Download dataset

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.fashion_mnist.load_data()

#train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model = Sequential([
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 1)),
    layers.Conv2D(16, (3,3), padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, (3,3), padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, (3,3), padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(10)
])

model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)                │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 28, 28, 16)          │             160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 14, 14, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 14, 14, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 7, 7, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 7, 7, 64)            │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 3, 3, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 576)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 98,442 (384.54 KB)
#  Trainable params: 98,442 (384.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'])

# %%
epochs=20
history = model.fit(
  train_images,
  train_labels,
  validation_data=(test_images, test_labels),
  epochs=epochs,
)
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 62s 32ms/step - accuracy: 0.7562 - loss: 0.6649 - val_accuracy: 0.8799 - val_loss: 0.3362
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 80s 31ms/step - accuracy: 0.8836 - loss: 0.3149 - val_accuracy: 0.8960 - val_loss: 0.2931
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 82s 31ms/step - accuracy: 0.9070 - loss: 0.2540 - val_accuracy: 0.8968 - val_loss: 0.2847
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 82s 31ms/step - accuracy: 0.9152 - loss: 0.2259 - val_accuracy: 0.9068 - val_loss: 0.2599
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 82s 31ms/step - accuracy: 0.9259 - loss: 0.2034 - val_accuracy: 0.9085 - val_loss: 0.2561
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 60s 32ms/step - accuracy: 0.9315 - loss: 0.1814 - val_accuracy: 0.9105 - val_loss: 0.2488
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 81s 31ms/step - accuracy: 0.9385 - loss: 0.1654 - val_accuracy: 0.9115 - val_loss: 0.2504
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 81s 31ms/step - accuracy: 0.9432 - loss: 0.1496 - val_accuracy: 0.9125 - val_loss: 0.2467
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 59s 31ms/step - accuracy: 0.9506 - loss: 0.1319 - val_accuracy: 0.9012 - val_loss: 0.3015
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 59s 31ms/step - accuracy: 0.9545 - loss: 0.1190 - val_accuracy: 0.9127 - val_loss: 0.2803
# Epoch 11/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 79s 30ms/step - accuracy: 0.9575 - loss: 0.1110 - val_accuracy: 0.9101 - val_loss: 0.2895
# Epoch 12/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 84s 31ms/step - accuracy: 0.9640 - loss: 0.0982 - val_accuracy: 0.9121 - val_loss: 0.2884
# Epoch 13/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 81s 31ms/step - accuracy: 0.9662 - loss: 0.0916 - val_accuracy: 0.9098 - val_loss: 0.3220
# Epoch 14/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 79s 30ms/step - accuracy: 0.9701 - loss: 0.0795 - val_accuracy: 0.9134 - val_loss: 0.3088
# Epoch 15/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 58s 31ms/step - accuracy: 0.9713 - loss: 0.0757 - val_accuracy: 0.9141 - val_loss: 0.3243
# Epoch 16/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 82s 31ms/step - accuracy: 0.9751 - loss: 0.0672 - val_accuracy: 0.9105 - val_loss: 0.3733
# Epoch 17/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 55s 30ms/step - accuracy: 0.9758 - loss: 0.0626 - val_accuracy: 0.9106 - val_loss: 0.3692
# Epoch 18/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 84s 31ms/step - accuracy: 0.9770 - loss: 0.0593 - val_accuracy: 0.9125 - val_loss: 0.3733
# Epoch 19/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 83s 31ms/step - accuracy: 0.9805 - loss: 0.0518 - val_accuracy: 0.9152 - val_loss: 0.4277
# Epoch 20/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 80s 30ms/step - accuracy: 0.9807 - loss: 0.0500 - val_accuracy: 0.9175 - val_loss: 0.4078

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# The model starts to overfit, so we will need to add some regularization to limit this.

# %% [markdown]
# ### Strategies to limit overfitting
#
# * Increasing training data size
# * Data augmentation to increase data complexity
# * Adding dropout layers
# * Adding Regularization parameters (e.g. kernel_regularizer=regularizers.l2(l=0.01))
# * Adding batch normalization
# * Early stopping
# * Simplifying the model (reducing the number of layers)

# %% [markdown]
# Data augmentation

# %%
batch_size = 32
img_width = 28
img_height = 28

data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  1)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
model = Sequential([
    data_augmentation,
    layers.Rescaling(1./255),
    layers.Conv2D(16, (3,3), padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, (3,3), padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, (3,3), padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(10)
])

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_1 (Sequential)            │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_1 (Rescaling)              │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 28, 28, 16)          │             160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 14, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 14, 14, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 7, 7, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 7, 7, 64)            │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 3, 3, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 576)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 98,442 (384.54 KB)
#  Trainable params: 98,442 (384.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Compile model

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'])

# %% [markdown]
# Early Stopping

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, mode='auto', restore_best_weights=True)
checkpoint = ModelCheckpoint('model_weights.h5.keras', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5)

callbacks = [early_stopping, checkpoint, reduce_lr]

# %% [markdown]
# Train the model with data augmentation and early stopping.

# %%
epochs=25
history = model.fit(
  train_images,
  train_labels,
  validation_data=(test_images, test_labels),
  epochs=epochs,
  callbacks=callbacks
)
# Out:
# Epoch 1/25
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6575 - loss: 0.9238
# Epoch 1: val_accuracy improved from -inf to 0.77970, saving model to model_weights.h5.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 67s 34ms/step - accuracy: 0.6576 - loss: 0.9236 - val_accuracy: 0.7797 - val_loss: 0.5968 - learning_rate: 0.0010
# Epoch 2/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8109 - loss: 0.5135
# Epoch 2: val_accuracy improved from 0.77970 to 0.81410, saving model to model_weights.h5.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 64s 34ms/step - accuracy: 0.8109 - loss: 0.5135 - val_accuracy: 0.8141 - val_loss: 0.5055 - learning_rate: 0.0010
# Epoch 3/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8372 - loss: 0.4357
# Epoch 3: val_accuracy improved from 0.81410 to 0.84070, saving model to model_weights.h5.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 83s 35ms/step - accuracy: 0.8372 - loss: 0.4357 - val_accuracy: 0.8407 - val_loss: 0.4505 - learning_rate: 0.0010
# Epoch 4/25
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8511 - loss: 0.4039
# Epoch 4: val_accuracy improved from 0.84070 to 0.86450, saving model to model_weights.h5.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 81s 34ms/step - accuracy: 0.8511 - loss: 0.4039 - val_accuracy: 0.8645 - val_loss: 0.3742 - learning_rate: 0.0010
# Epoch 5/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8619 - loss: 0.3747
# Epoch 5: val_accuracy did not improve from 0.86450
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 84s 35ms/step - accuracy: 0.8619 - loss: 0.3747 - val_accuracy: 0.8620 - val_loss: 0.3776 - learning_rate: 0.0010
# Epoch 6/25
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8657 - loss: 0.3591
# Epoch 6: val_accuracy improved from 0.86450 to 0.86630, saving model to model_weights.h5.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 79s 34ms/step - accuracy: 0.8657 - loss: 0.3591 - val_accuracy: 0.8663 - val_loss: 0.3720 - learning_rate: 0.0010
# Epoch 7/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8711 - loss: 0.3430
# Epoch 7: val_accuracy improved from 0.86630 to 0.87380, saving model to model_weights.h5.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 83s 34ms/step - accuracy: 0.8711 - loss: 0.3430 - val_accuracy: 0.8738 - val_loss: 0.3547 - learning_rate: 0.0010
# Epoch 8/25
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8739 - loss: 0.3324
# Epoch 8: val_accuracy did not improve from 0.87380
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 82s 34ms/step - accuracy: 0.8739 - loss: 0.3324 - val_accuracy: 0.8691 - val_loss: 0.3572 - learning_rate: 0.0010
# Epoch 9/25
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8826 - loss: 0.3107
# Epoch 9: val_accuracy did not improve from 0.87380
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 81s 34ms/step - accuracy: 0.8826 - loss: 0.3108 - val_accuracy: 0.8670 - val_loss: 0.3600 - learning_rate: 0.0010
# Epoch 10/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8870 - loss: 0.3056
# Epoch 10: val_accuracy did not improve from 0.87380
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 82s 34ms/step - accuracy: 0.8870 - loss: 0.3056 - val_accuracy: 0.8717 - val_loss: 0.3518 - learning_rate: 0.0010
# Epoch 11/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8859 - loss: 0.3034
# Epoch 11: val_accuracy did not improve from 0.87380
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 82s 34ms/step - accuracy: 0.8859 - loss: 0.3034 - val_accuracy: 0.8711 - val_loss: 0.3629 - learning_rate: 0.0010
# Epoch 12/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8897 - loss: 0.2945
# Epoch 12: val_accuracy did not improve from 0.87380
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 83s 34ms/step - accuracy: 0.8897 - loss: 0.2945 - val_accuracy: 0.8715 - val_loss: 0.3551 - learning_rate: 0.0010
# Epoch 13/25
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8903 - loss: 0.2914
# Epoch 13: val_accuracy improved from 0.87380 to 0.88460, saving model to model_weights.h5.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 81s 34ms/step - accuracy: 0.8903 - loss: 0.2914 - val_accuracy: 0.8846 - val_loss: 0.3203 - learning_rate: 0.0010
# Epoch 14/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8895 - loss: 0.2919
# Epoch 14: val_accuracy improved from 0.88460 to 0.88940, saving model to model_weights.h5.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 81s 33ms/step - accuracy: 0.8895 - loss: 0.2919 - val_accuracy: 0.8894 - val_loss: 0.3097 - learning_rate: 0.0010
# Epoch 15/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8936 - loss: 0.2831
# Epoch 15: val_accuracy did not improve from 0.88940
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 63s 34ms/step - accuracy: 0.8936 - loss: 0.2831 - val_accuracy: 0.8849 - val_loss: 0.3227 - learning_rate: 0.0010
# Epoch 16/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8971 - loss: 0.2774
# Epoch 16: val_accuracy did not improve from 0.88940
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 84s 35ms/step - accuracy: 0.8971 - loss: 0.2774 - val_accuracy: 0.8820 - val_loss: 0.3252 - learning_rate: 0.0010
# Epoch 17/25
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8975 - loss: 0.2758
# Epoch 17: val_accuracy did not improve from 0.88940
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 80s 34ms/step - accuracy: 0.8975 - loss: 0.2758 - val_accuracy: 0.8867 - val_loss: 0.3174 - learning_rate: 0.0010
# Epoch 18/25
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8989 - loss: 0.2711
# Epoch 18: val_accuracy did not improve from 0.88940
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 64s 34ms/step - accuracy: 0.8989 - loss: 0.2711 - val_accuracy: 0.8878 - val_loss: 0.3260 - learning_rate: 0.0010
# Epoch 19/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9012 - loss: 0.2662
# Epoch 19: val_accuracy improved from 0.88940 to 0.89290, saving model to model_weights.h5.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 63s 34ms/step - accuracy: 0.9012 - loss: 0.2662 - val_accuracy: 0.8929 - val_loss: 0.3062 - learning_rate: 0.0010
# Epoch 20/25
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9011 - loss: 0.2636
# Epoch 20: val_accuracy improved from 0.89290 to 0.89820, saving model to model_weights.h5.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 83s 34ms/step - accuracy: 0.9011 - loss: 0.2636 - val_accuracy: 0.8982 - val_loss: 0.2937 - learning_rate: 0.0010
# Epoch 21/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9011 - loss: 0.2609
# Epoch 21: val_accuracy did not improve from 0.89820
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 64s 34ms/step - accuracy: 0.9011 - loss: 0.2609 - val_accuracy: 0.8891 - val_loss: 0.3175 - learning_rate: 0.0010
# Epoch 22/25
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9016 - loss: 0.2612
# Epoch 22: val_accuracy did not improve from 0.89820
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 64s 34ms/step - accuracy: 0.9016 - loss: 0.2612 - val_accuracy: 0.8952 - val_loss: 0.2917 - learning_rate: 0.0010
# Epoch 23/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9030 - loss: 0.2575
# Epoch 23: val_accuracy did not improve from 0.89820
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 81s 34ms/step - accuracy: 0.9030 - loss: 0.2575 - val_accuracy: 0.8939 - val_loss: 0.3004 - learning_rate: 0.0010
# Epoch 24/25
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9031 - loss: 0.2578
# Epoch 24: val_accuracy did not improve from 0.89820
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 83s 34ms/step - accuracy: 0.9031 - loss: 0.2578 - val_accuracy: 0.8860 - val_loss: 0.3202 - learning_rate: 0.0010
# Epoch 25/25
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9036 - loss: 0.2555
# Epoch 25: val_accuracy did not improve from 0.89820
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 81s 34ms/step - accuracy: 0.9036 - loss: 0.2555 - val_accuracy: 0.8920 - val_loss: 0.3059 - learning_rate: 0.0010

# %% [markdown]
# Visualize training accuracy and loss

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Predict image

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

model = keras.models.load_model('model_weights.h5.keras')

img = keras.utils.load_img(
    "/content/drive/MyDrive/r1.jpg",
    target_size=(img_height, img_width),
    color_mode="grayscale")
plt.imshow(img)

img_array = keras.utils.img_to_array(img)
img_array = keras.ops.expand_dims(img_array, 0)  # Create batch axis

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print(score)
print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# tf.Tensor(
# [7.3698741e-01 2.4609855e-01 1.6797824e-02 8.4405610e-06 6.4307911e-05
#  6.9580852e-07 4.1784067e-05 1.2982204e-12 1.0466773e-06 1.7517530e-10], shape=(10,), dtype=float32)
# This image most likely belongs to T-shirt/top with a 73.70 percent confidence.
